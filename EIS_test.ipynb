# %%
from impedance import preprocessing

# Load data from the example EIS data
frequencies, Z = preprocessing.readCSV('ASCII files/1.00 V 10 cycle.txt')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 4
#       1 from impedance import preprocessing
#       3 # Load data from the example EIS data
# ----> 4 frequencies, Z = preprocessing.readCSV('ASCII files/1.00 V 10 cycle.txt')
#
# File ~/.python/current/lib/python3.10/site-packages/impedance/preprocessing.py:413, in readCSV(filename)
#     395 """ function for reading plain csv files
#     396
#     397 Parameters
#    (...)
#     409
#     410 """
#     411 data = np.genfromtxt(filename, delimiter=',')
# --> 413 f = data[:, 0]
#     414 Z = data[:, 1] + 1j*data[:, 2]
#     416 return f, Z
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
